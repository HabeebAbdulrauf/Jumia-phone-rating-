# %%
import pandas as pd

import numpy as np

# %%
Igr = pd.read_csv(r"C:\Users\User\Desktop\AI AND DATA SCIENCE BOOTCAMP\DATA SCIENCE\Jumia_clean Project work.csv")

# %%
Igr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   brand           508 non-null    object
#  1   current_price   508 non-null    int64
#  2   old_price       508 non-null    int64
#  3   discount        508 non-null    int64
#  4   description     508 non-null    object
#  5   ratings         508 non-null    float64
#  6   times_reviewed  508 non-null    int64
#  7   rom             508 non-null    float64
#  8   ram             508 non-null    float64
#  9   battery         508 non-null    float64
#  10  camera          508 non-null    float64
#  11  sim port        508 non-null    object
#  12  screen_dim      508 non-null    float64
#  13  android_ver     508 non-null    float64
# dtypes: float64(7), int64(4), object(3)
# memory usage: 55.7+ KB

# %%
Igr.head(5)
# Out:
#      brand  current_price  old_price  discount  \
# 0   Gionee          48000      73630       -35
# 1    Nokia          59520     119660       -50
# 2  UMIDIGI          25990      29990       -13
# 3    Nokia          42990      70485       -39
# 4  UMIDIGI          25990      29990       -13
#
#                                          description  ratings  times_reviewed  \
# 0  Gionee K3 (M100) 4GB+64GB 6.22 Inch HD+ Androi...     3.50              10
# 1  7， 5.2-inch (4GB, 64GB ROM) Android 7.1, 16MP ...     3.80              10
# 2  A3S Android 10 Global Band 3950mAh 5.7" Smartp...     4.30              99
# 3  3.2 3GB RAM 32GB 6.26 Inch 13MP Camera Dual SI...     4.05             104
# 4  A3S Android 10 Global Band 3950mAh 5.7" Smartp...     3.90             148
#
#     rom  ram  battery  camera      sim port  screen_dim  android_ver
# 0  64.0  4.0   5000.0    13.0      Dual SIM        6.22          8.1
# 1  64.0  4.0   3000.0    16.0      Dual Sim        5.20          7.1
# 2  32.0  4.0   3950.0    13.0  Triple Slots        5.70         10.0
# 3  32.0  3.0   4000.0    13.0      Dual SIM        6.26          9.0
# 4  32.0  4.0   3950.0    13.0  Triple Slots        5.70         10.0

# %%
# Igr['brand'].replace(Phones_int, Phones, inplace = True)

Igr.rename(columns={'brand': 'Phone', 'ratings': 'clientrating'}, inplace=True)

# %%
Igr.head(3)
# Out:
#      Phone  current_price  old_price  discount  \
# 0   Gionee          48000      73630       -35
# 1    Nokia          59520     119660       -50
# 2  UMIDIGI          25990      29990       -13
#
#                                          description  clientrating  \
# 0  Gionee K3 (M100) 4GB+64GB 6.22 Inch HD+ Androi...           3.5
# 1  7， 5.2-inch (4GB, 64GB ROM) Android 7.1, 16MP ...           3.8
# 2  A3S Android 10 Global Band 3950mAh 5.7" Smartp...           4.3
#
#    times_reviewed   rom  ram  battery  camera      sim port  screen_dim  \
# 0              10  64.0  4.0   5000.0    13.0      Dual SIM        6.22
# 1              10  64.0  4.0   3000.0    16.0      Dual Sim        5.20
# 2              99  32.0  4.0   3950.0    13.0  Triple Slots        5.70
#
#    android_ver
# 0          8.1
# 1          7.1
# 2         10.0

# %%
Igr.value_counts()
# Out:
# Phone    current_price  old_price  discount  description                                                                                                         clientrating  times_reviewed  rom   ram  battery  camera  sim port  screen_dim  android_ver
# ZTE      36000          0           0        ZTE Blade A520 Smart Phone 1GB+8GB 5.0 Inch Quad Core Android 6.0 Dual SIM 8MP Cellphone                            4.00          1               8.0   1.0  4000.0   8.0     Dual SIM  5.0         6.0            1
# Infinix  65000          109000     -40       Zero 4 (X555) 5.5-Inch IPS LCD (3GB RAM,32GB ROM) Android 6.0 Marshmallow, 16MP + 8MP Dual SIM 4G LTE Smartphone -  3.00          1               32.0  3.0  4000.0   16.0    Dual SIM  5.5         6.0            1
# Huawei   250000         0           0        Y9 (2019) 6.5" (64GB+ 4GB Ram) Android 8.1 Oreo, (16MP + 2MP)+(13MP + 2MP) 4000 MAh -Midnight Black                 4.70          96              64.0  4.0  4000.0   16.0    Dual SIM  6.5         8.1            1
# Infinix  39500          45000      -12       Smart 4, 6.6-Inch HD+, (1GB,16GB ROM) Android 9.0 Pie, 5MP + 8MP, Dual SIM, 4000mAh 4G Smartphone - Cosmic Purple   5.00          1               16.0  1.0  4000.0   5.0     Dual SIM  6.6         9.0            1
#          42000          0           0        HOT 7 (X624B) 32GB+2GB, 6.2", 3G, 4000 MAh, Dual SIM, Fingerprint, 13MP + 8MP - Champagne Gold                      4.35          221             32.0  2.0  4000.0   13.0    Dual SIM  6.2         8.1            1
#                                                                                                                                                                                                                                                                ..
# Sailf    14399          27599      -48       New Android Smartphone Face Recognition 5.0 Inch Dual Card 512M+4GB                                                 3.80          5               32.0  4.0  4000.0   13.0    Dual SIM  5.0         8.1            1
# Samsung  8710           12443      -30       KUH T3 Rugged Phone, 2.4 Inch, Waterproof Dustproof Shockproof, 2400mAh Battery - Black                             5.00          1               32.0  4.0  2400.0   13.0    Dual SIM  2.4         8.1            1
#          18840          26296      -28       O6 Android 6.0 1GB +8GB MT6572 Dual Core 5 Inch LCD 960*540 Mobile Phone - White                                    4.00          3               8.0   1.0  4000.0   13.0    Dual SIM  5.0         6.0            1
#          23990          100000     -76       Galaxy S4 I9507V 4G Smartphone 5.0'' 2600mAh FHD 13MP+2MP 2GB+16GB Mobile Phone-White                               3.80          67              16.0  2.0  2600.0   13.0    Dual SIM  5.0         8.1            1
# AfriOne  61000          70000      -13       Afrione Cygnus X 20mp Ai Selfie & Rear Camera – 6.53″ Waterdrop Full Screen Display – 4GB/64GB                      3.00          5               64.0  4.0  4000.0   13.0    Dual SIM  5.8         8.1            1
# Length: 508, dtype: int64

# %%
Igr.keys()
# Out:
# Index(['Phone', 'current_price', 'old_price', 'discount', 'description',
#        'clientrating', 'times_reviewed', 'rom', 'ram', 'battery', 'camera',
#        'sim port', 'screen_dim', 'android_ver'],
#       dtype='object')

# %%
Igr.dropna()
# Out:
#        Phone  current_price  old_price  discount  \
# 0     Gionee          48000      73630       -35
# 1      Nokia          59520     119660       -50
# 2    UMIDIGI          25990      29990       -13
# 3      Nokia          42990      70485       -39
# 4    UMIDIGI          25990      29990       -13
# ..       ...            ...        ...       ...
# 503   XIAOMI          63760     121500       -48
# 504   XIAOMI          63760     121500       -48
# 505     Itel          23000          0         0
# 506     Itel          20499      25000       -18
# 507     Itel          29490      30000        -2
#
#                                            description  clientrating  \
# 0    Gionee K3 (M100) 4GB+64GB 6.22 Inch HD+ Androi...          3.50
# 1    7， 5.2-inch (4GB, 64GB ROM) Android 7.1, 16MP ...          3.80
# 2    A3S Android 10 Global Band 3950mAh 5.7" Smartp...          4.30
# 3    3.2 3GB RAM 32GB 6.26 Inch 13MP Camera Dual SI...          4.05
# 4    A3S Android 10 Global Band 3950mAh 5.7" Smartp...          3.90
# ..                                                 ...           ...
# 503  Redmi Note8, 4G, 6.3", 4GB RAM + 64GB ROM, MIU...          5.00
# 504  Redmi Note8, 4G, 6.3 Inch (4GB RAM + 64GB ROM)...          5.00
# 505  A33 5.0" Screen, Android 8.1, 16GB ROM + 1GB R...          4.25
# 506  A16plus - 5.0"Screen 8GB ROM-1GB RAM, Android ...          5.00
# 507  P33 Plus 6.0" Android 8.1  (16GB+1GB RAM,) Dua...          4.40
#
#      times_reviewed   rom  ram  battery  camera      sim port  screen_dim  \
# 0                10  64.0  4.0   5000.0    13.0      Dual SIM        6.22
# 1                10  64.0  4.0   3000.0    16.0      Dual Sim        5.20
# 2                99  32.0  4.0   3950.0    13.0  Triple Slots        5.70
# 3               104  32.0  3.0   4000.0    13.0      Dual SIM        6.26
# 4               148  32.0  4.0   3950.0    13.0  Triple Slots        5.70
# ..              ...   ...  ...      ...     ...           ...         ...
# 503               1  64.0  4.0   4000.0    13.0      Dual SIM        6.30
# 504               1  64.0  4.0   4000.0    13.0      Dual SIM        6.30
# 505             212  16.0  1.0   2200.0     2.0      Dual SIM        5.00
# 506               1   8.0  1.0   4000.0     5.0      Dual SIM        5.00
# 507             233  16.0  1.0   4000.0    13.0      Dual SIM        6.00
#
#      android_ver
# 0            8.1
# 1            7.1
# 2           10.0
# 3            9.0
# 4           10.0
# ..           ...
# 503          8.1
# 504          8.1
# 505          8.1
# 506          8.1
# 507          8.1
#
# [508 rows x 14 columns]

# %%
Igr.clientrating.mean()
# Out:
# 4.178838582677163

# %%
Igr.clientrating.median()
# Out:
# 4.35

# %%
Igr.clientrating.mode()
# Out:
# 0    5.0
# dtype: float64

# %%
Igr.head(3)
# Out:
#      Phone  current_price  old_price  discount  \
# 0   Gionee          48000      73630       -35
# 1    Nokia          59520     119660       -50
# 2  UMIDIGI          25990      29990       -13
#
#                                          description  clientrating  \
# 0  Gionee K3 (M100) 4GB+64GB 6.22 Inch HD+ Androi...           3.5
# 1  7， 5.2-inch (4GB, 64GB ROM) Android 7.1, 16MP ...           3.8
# 2  A3S Android 10 Global Band 3950mAh 5.7" Smartp...           4.3
#
#    times_reviewed   rom  ram  battery  camera      sim port  screen_dim  \
# 0              10  64.0  4.0   5000.0    13.0      Dual SIM        6.22
# 1              10  64.0  4.0   3000.0    16.0      Dual Sim        5.20
# 2              99  32.0  4.0   3950.0    13.0  Triple Slots        5.70
#
#    android_ver
# 0          8.1
# 1          7.1
# 2         10.0

# %%
Abstpf = Igr[Igr["clientrating"] == 3.5]

# %%
Abstpf.mean()
# Out:
# current_price     48654.000
# old_price         33310.800
# discount            -18.400
# clientrating          3.500
# times_reviewed       16.000
# rom                  32.000
# ram                   3.000
# battery            4200.000
# camera               14.200
# screen_dim            5.484
# android_ver           7.880
# dtype: float64
